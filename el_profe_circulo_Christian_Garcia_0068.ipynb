# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280068-collab/EPPL-rea-de-un-triangulo-mis-im-genes/blob/main/el_profe_circulo_Christian_Garcia_0068.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Christian Garcia Jimenez fecha 25/03/2026
# ---
# # Calcula Area de un triangulo ✈
# ---
# ![logo de markdown](https://raw.githubusercontent.com/a25308051280068-collab/EPPL-rea-de-un-triangulo-mis-im-genes/refs/heads/main/triangulo.PNG)
# ---
#
# # Formula para calcular area
# $B*H/2
# ---
#
# ## Datos de entrada
# $A$ ?
# $B$ ?
# ---
# ## Diagrama de flujo
#
# ![logo de markdown](https://raw.githubusercontent.com/a25308051280068-collab/EPPL-rea-de-un-triangulo-mis-im-genes/refs/heads/main/diagrama%20de%20flujo%20DF.PNG)
# ---

# %%
# calcula area de un triangulo
# Variable A, B, H
# Formula A = B*H/2
# capturar el valor de A
import math
print("Calcular area de un triangulo")
B = float(input("Dame el valor de la B: " ))
H = float(input("Dame el valor de la A:  " ))
A = (B*H)/2
print("El area del triangulo es: ", A)
print("Christian Garcia NL = 21")
# Out:
# Calcular area de un triangulo
# Dame el valor de la base: 20
# Dame el valor de la altura: 20
# El area del triangulo es:  200.0
# Christian Garcia NL = 21

# %% [markdown]
# # relacion entre codigo y DF en tellegram
# ![logo de markdown](https://raw.githubusercontent.com/a25308051280068-collab/EPPL-rea-de-un-triangulo-mis-im-genes/refs/heads/main/formula%20y%20diagrama%20de%20flujo.PNG)
# ---
